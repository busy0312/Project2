# %%
#Import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import SQL_key

# %%
# Read csv file
path_intake="raw_data/Austin_Animal_Center_Intakes.csv"
path_outcome="raw_data/Austin_Animal_Center_Outcomes.csv"

# %%
animal_outcome=pd.read_csv(path_outcome)
animal_outcome.head()
# Out:
#   Animal ID        Name                DateTime               MonthYear  \
# 0   A794011       Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359       Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A720371       Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 3   A674754         NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# 4   A689724  *Donatello  10/18/2014 06:52:00 PM  10/18/2014 06:52:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# 1    07/12/2017     Adoption             NaN         Dog    Neutered Male
# 2    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 3    03/12/2014     Transfer         Partner         Cat      Intact Male
# 4    08/01/2014     Adoption             NaN         Cat    Neutered Male
#
#   Age upon Outcome                               Breed              Color
# 0          2 years              Domestic Shorthair Mix  Brown Tabby/White
# 1           1 year             Chihuahua Shorthair Mix        White/Brown
# 2         4 months  Anatol Shepherd/Labrador Retriever               Buff
# 3           6 days              Domestic Shorthair Mix       Orange Tabby
# 4         2 months              Domestic Shorthair Mix              Black

# %%
# drop columns
animal_outcome_df=animal_outcome.drop(columns=['Outcome Subtype','MonthYear'])
animal_outcome_df.head()
# Out:
#   Animal ID        Name                DateTime Date of Birth Outcome Type  \
# 0   A794011       Chunk  05/08/2019 06:20:00 PM    05/02/2017    Rto-Adopt
# 1   A776359       Gizmo  07/18/2018 04:02:00 PM    07/12/2017     Adoption
# 2   A720371       Moose  02/13/2016 05:59:00 PM    10/08/2015     Adoption
# 3   A674754         NaN  03/18/2014 11:47:00 AM    03/12/2014     Transfer
# 4   A689724  *Donatello  10/18/2014 06:52:00 PM    08/01/2014     Adoption
#
#   Animal Type Sex upon Outcome Age upon Outcome  \
# 0         Cat    Neutered Male          2 years
# 1         Dog    Neutered Male           1 year
# 2         Dog    Neutered Male         4 months
# 3         Cat      Intact Male           6 days
# 4         Cat    Neutered Male         2 months
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2  Anatol Shepherd/Labrador Retriever               Buff
# 3              Domestic Shorthair Mix       Orange Tabby
# 4              Domestic Shorthair Mix              Black

# %%
# load file
animal_intake=pd.read_csv(path_intake)
animal_intake.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
#drop columns
animal_intake_df=animal_intake.drop(columns=['Found Location','MonthYear','Breed','Color','Name','Intake Condition','Animal Type',"Sex upon Intake"])
animal_intake_df.head()
# Out:
#   Animal ID                DateTime Intake Type Age upon Intake
# 0   A786884  01/03/2019 04:19:00 PM       Stray         2 years
# 1   A706918  07/05/2015 12:59:00 PM       Stray         8 years
# 2   A724273  04/14/2016 06:43:00 PM       Stray       11 months
# 3   A665644  10/21/2013 07:59:00 AM       Stray         4 weeks
# 4   A682524  06/29/2014 10:38:00 AM       Stray         4 years

# %%
# merge two csv
combined=pd.merge(animal_outcome_df,animal_intake_df,on="Animal ID",how="left")
combined.head()
# Out:
#   Animal ID   Name              DateTime_x Date of Birth Outcome Type  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM    05/02/2017    Rto-Adopt
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM    07/12/2017     Adoption
# 2   A720371  Moose  02/13/2016 05:59:00 PM    10/08/2015     Adoption
# 3   A720371  Moose  02/13/2016 05:59:00 PM    10/08/2015     Adoption
# 4   A674754    NaN  03/18/2014 11:47:00 AM    03/12/2014     Transfer
#
#   Animal Type Sex upon Outcome Age upon Outcome  \
# 0         Cat    Neutered Male          2 years
# 1         Dog    Neutered Male           1 year
# 2         Dog    Neutered Male         4 months
# 3         Dog    Neutered Male         4 months
# 4         Cat      Intact Male           6 days
#
#                                 Breed              Color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2  Anatol Shepherd/Labrador Retriever               Buff
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#                DateTime_y      Intake Type Age upon Intake
# 0  05/02/2019 04:51:00 PM  Owner Surrender         2 years
# 1  07/12/2018 12:46:00 PM            Stray          1 year
# 2  02/08/2016 11:05:00 AM            Stray        4 months
# 3  02/15/2016 10:37:00 AM  Owner Surrender        4 months
# 4  03/18/2014 07:11:00 AM            Stray          6 days

# %%
#rename columns and sort by date
combined_df=combined.rename(columns={
    "DateTime_x": "DateTime_Outcome", "DateTime_y": "DateTime_Intake","Animal ID":"Animal_ID",
    "Date of Birth":"Date_of_Birth","Outcome Type":"Outcome_Type","Animal Type":"Animal_Type",
    "Sex upon Outcome":"Sex_upon_Outcome","Age upon Outcome":"Age_upon_Outcome",
    "Intake Type":"Intake_Type","Age upon Intake":"Age_upon_Intake"

})
combined_df=combined_df.sort_values(by='Animal_ID',ascending=False)
combined_df.head()
# Out:
#        Animal_ID       Name        DateTime_Outcome Date_of_Birth  \
# 152748   A818085  Harlequin  06/01/2020 06:19:00 PM    04/16/2020
# 152734   A818074        NaN  06/01/2020 01:19:00 PM    05/10/2020
# 152739   A818073        NaN  06/01/2020 01:18:00 PM    05/10/2020
# 152735   A818072        NaN  06/01/2020 01:18:00 PM    05/10/2020
# 152738   A818071        NaN  06/01/2020 01:17:00 PM    05/10/2020
#
#        Outcome_Type Animal_Type Sex_upon_Outcome Age_upon_Outcome  \
# 152748     Transfer         Dog    Intact Female          1 month
# 152734     Transfer         Cat      Intact Male          3 weeks
# 152739     Transfer         Cat      Intact Male          3 weeks
# 152735     Transfer         Cat      Intact Male          3 weeks
# 152738     Transfer         Cat    Intact Female          3 weeks
#
#                          Breed              Color         DateTime_Intake  \
# 152748            Pit Bull Mix        Black/White  06/01/2020 01:15:00 PM
# 152734  Domestic Shorthair Mix  Brown Tabby/White  06/01/2020 12:09:00 PM
# 152739  Domestic Shorthair Mix  Brown Tabby/White  06/01/2020 12:09:00 PM
# 152735  Domestic Shorthair Mix        Black Smoke  06/01/2020 12:09:00 PM
# 152738  Domestic Shorthair Mix             Calico  06/01/2020 12:09:00 PM
#
#             Intake_Type Age_upon_Intake
# 152748  Owner Surrender         1 month
# 152734            Stray         3 weeks
# 152739            Stray         3 weeks
# 152735            Stray         3 weeks
# 152738            Stray         3 weeks

# %%
# duplicated columns
combined_df=combined_df.drop_duplicates(subset='Animal_ID', keep='first')
# only keep Dogs and Cats
combined_df=combined_df[(combined_df['Animal_Type']=='Dog')|(combined_df['Animal_Type']=='Cat')]

# %%
combined_df.head()
# Out:
#        Animal_ID       Name        DateTime_Outcome Date_of_Birth  \
# 152748   A818085  Harlequin  06/01/2020 06:19:00 PM    04/16/2020
# 152734   A818074        NaN  06/01/2020 01:19:00 PM    05/10/2020
# 152739   A818073        NaN  06/01/2020 01:18:00 PM    05/10/2020
# 152735   A818072        NaN  06/01/2020 01:18:00 PM    05/10/2020
# 152738   A818071        NaN  06/01/2020 01:17:00 PM    05/10/2020
#
#        Outcome_Type Animal_Type Sex_upon_Outcome Age_upon_Outcome  \
# 152748     Transfer         Dog    Intact Female          1 month
# 152617   Labrador Retriever Mix               Black  05/26/2020 01:31:00 PM
# 152672       Labrador Retriever               Brown  05/26/2020 10:52:00 AM
# 152584                 Pit Bull                Blue  05/26/2020 08:48:00 AM
#
#             Intake_Type Age_upon_Intake
# 152748  Owner Surrender         1 month
# 152734            Stray         3 weeks
# 152739            Stray         3 weeks
# 152735            Stray         3 weeks
# 152738            Stray         3 weeks
# 152732            Stray         2 weeks
# 152737            Stray         2 years
# 152733            Stray         2 years
# 152715    Public Assist         1 month
# 152747            Stray         6 years
# 152705            Stray          2 days
# 152704            Stray          2 days
# 152713            Stray         2 years
# 152736            Stray         2 years
# 152706            Stray         2 years
# 152685            Stray         1 weeks
# 152687            Stray         1 month
# 152693            Stray         2 years
# 152694            Stray        2 months
# 152686            Stray         2 weeks
# 152683            Stray         2 years
# 152684            Stray         1 weeks
# 152697            Stray         2 years
# 152674            Stray         2 years
# 152679            Stray         3 years
# 152663            Stray          2 days
# 152707        Abandoned         2 years
# 152653            Stray         2 weeks
# 152655            Stray         2 weeks
# 152651            Stray         2 weeks
# 152654            Stray         2 weeks
# 152657            Stray         1 month
# 152643            Stray          1 year
# 152652            Stray         2 weeks
# 152625            Stray         4 weeks
# 152708            Stray         2 years
# 152744            Stray          1 year
# 152617  Owner Surrender        2 months
# 152672            Stray         6 years
# 152584  Owner Surrender         1 month

# %%
# Push transformed CSV file to folder
combined_df.to_csv("Animals.csv", index=False, header=True)

# %%
# Create Postgress connection
rds_connection_string = f'postgres:{SQL_key}@localhost:5432/animals_db'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# View tables
engine.table_names()
# Out:
# ['austin_animals']

# %%
# Push transformed file to Postgres
combined_df.to_sql(name="austin_animals", con=engine, if_exists='append', index=False)

# %%
# Query file from Postgres
pd.read_sql_query('select * from austin_Animals', con=engine).head()
# Out:
#          Animal_ID       Name DateTime_Outcome Date_of_Birth Outcome_Type  \
# 0  A818085          Harlequin       2020-06-01    2020-04-16     Transfer
# 1  A818074               None       2020-06-01    2020-05-10     Transfer
# 2  A818073               None       2020-06-01    2020-05-10     Transfer
# 3  A818072               None       2020-06-01    2020-05-10     Transfer
# 4  A818071               None       2020-06-01    2020-05-10     Transfer
#
#   Animal_Type Sex_upon_Outcome Age_upon_Outcome                   Breed  \
# 0         Dog    Intact Female          1 month            Pit Bull Mix
# 1         Cat      Intact Male          3 weeks  Domestic Shorthair Mix
# 2         Cat      Intact Male          3 weeks  Domestic Shorthair Mix
# 3         Cat      Intact Male          3 weeks  Domestic Shorthair Mix
# 4         Cat    Intact Female          3 weeks  Domestic Shorthair Mix
#
#                Color DateTime_Intake      Intake_Type Age_upon_Intake
# 0        Black/White      2020-06-01  Owner Surrender         1 month
# 1  Brown Tabby/White      2020-06-01            Stray         3 weeks
# 2  Brown Tabby/White      2020-06-01            Stray         3 weeks
# 3        Black Smoke      2020-06-01            Stray         3 weeks
# 4             Calico      2020-06-01            Stray         3 weeks
