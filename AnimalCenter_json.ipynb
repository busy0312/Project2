# %%
# Dependencies
import requests
import json

# %%
url="https://data.austintexas.gov/resource/9t4d-g238.json"
response=requests.get(url)
#response.text
#data=response.json()
#data[0]["id"]
#data[0]["title"]
#response.status_code
response.raise_for_status()

# %%
# Print the response object to the console
print(requests.get(url))
data=requests.get(url)
# Out:
# <Response [200]>

# %%
print(data.json())
# Out:
# [{'animal_id': 'A816523', 'name': 'Mrs. Norris', 'datetime': '2020-06-01T19:33:00.000', 'monthyear': '2020-06-01T19:33:00.000', 'date_of_birth': '2011-04-21T00:00:00.000', 'outcome_type': 'Adoption', 'animal_type': 'Cat', 'sex_upon_outcome': 'Spayed Female', 'age_upon_outcome': '9 years', 'breed': 'Domestic Medium Hair', 'color': 'Torbie'}, {'animal_id': 'A818085', 'name': 'Harlequin', 'datetime': '2020-06-01T18:19:00.000', 'monthyear': '2020-06-01T18:19:00.000', 'date_of_birth': '2020-04-16T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Intact Female', 'age_upon_outcome': '1 month', 'breed': 'Pit Bull Mix', 'color': 'Black/White'}, {'animal_id': 'A818029', 'name': 'Blue', 'datetime': '2020-06-01T17:44:00.000', 'monthyear': '2020-06-01T17:44:00.000', 'date_of_birth': '2014-05-31T00:00:00.000', 'outcome_type': 'Return to Owner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Spayed Female', 'age_upon_outcome': '6 years', 'breed': 'Labrador Retriever', 'color': 'Black'}, {'animal_id': 'A783957', 'name': 'Dino', 'datetime': '2020-06-01T16:43:00.000', 'monthyear': '2020-06-01T16:43:00.000', 'date_of_birth': '2016-11-09T00:00:00.000', 'outcome_type': 'Return to Owner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Neutered Male', 'age_upon_outcome': '3 years', 'breed': 'Chihuahua Shorthair Mix', 'color': 'Black/White'}, {'animal_id': 'A817802', 'datetime': '2020-06-01T15:26:00.000', 'monthyear': '2020-06-01T15:26:00.000', 'date_of_birth': '2019-05-26T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Neutered Male', 'age_upon_outcome': '1 year', 'breed': 'Dachshund/Chihuahua Shorthair', 'color': 'Black'}, {'animal_id': 'A818002', 'name': 'Piper', 'datetime': '2020-06-01T13:57:00.000', 'monthyear': '2020-06-01T13:57:00.000', 'date_of_birth': '2018-05-30T00:00:00.000', 'outcome_type': 'Return to Owner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Intact Female', 'age_upon_outcome': '2 years', 'breed': 'Vizsla', 'color': 'Brown'}, {'animal_id': 'A818050', 'datetime': '2020-06-01T13:25:00.000', 'monthyear': '2020-06-01T13:25:00.000', 'date_of_birth': '2018-06-01T00:00:00.000', 'outcome_type': 'Return to Owner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Intact Female', 'age_upon_outcome': '2 years', 'breed': 'Pug', 'color': 'Brown/Fawn'}, {'animal_id': 'A818049', 'datetime': '2020-06-01T13:24:00.000', 'monthyear': '2020-06-01T13:24:00.000', 'date_of_birth': '2018-06-01T00:00:00.000', 'outcome_type': 'Return to Owner', 'animal_type': 'Dog', 'sex_upon_outcome': 'Intact Female', 'age_upon_outcome': '2 years', 'breed': 'Pit Bull', 'color': 'White/Gray'}, {'animal_id': 'A818074', 'datetime': '2020-06-01T13:19:00.000', 'monthyear': '2020-06-01T13:19:00.000', 'date_of_birth': '2020-05-10T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'animal_type': 'Cat', 'sex_upon_outcome': 'Intact Male', 'age_upon_outcome': '3 weeks', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White'}, {'animal_id': 'A818073', 'datetime': '2020-06-01T13:18:00.000', 'monthyear': '2020-06-01T13:18:00.000', 'date_of_birth': '2020-05-10T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'animal_type': 'Cat', 'sex_upon_outcome': 'Intact Male', 'age_upon_outcome': '3 weeks', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White'}, {'animal_id': 'A818072', 'datetime': '2020-06-01T13:18:00.000', 'monthyear': '2020-06-01T13:18:00.000', 'date_of_birth': '2020-05-10T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'animal_type': 'Cat', 'sex_upon_outcome': 'Intact Male', 'age_upon_outcome': '3 weeks', 'breed': 'Domestic Shorthair Mix', 'color': 'Black Smoke'}, {'animal_id': 'A818068', 'datetime': '2020-06-01T13:17:00.000', 'monthyear': '2020-06-01T13:17:00.000', 'date_of_birth': '2020-05-13T00:00:00.000', 'outcome_type': 'Transfer', 'outcome_subtype': 'Partner', 'anima ...

# %%
raw_text=requests.get(url).text
raw_text
#load is for fils(string to python)/loads is string(python to string)
json.loads(raw_text)
json.loads(raw_text)[0]
# Out:
# {'animal_id': 'A816523',
#  'name': 'Mrs. Norris',
#  'datetime': '2020-06-01T19:33:00.000',
#  'monthyear': '2020-06-01T19:33:00.000',
#  'date_of_birth': '2011-04-21T00:00:00.000',
#  'outcome_type': 'Adoption',
#  'animal_type': 'Cat',
#  'sex_upon_outcome': 'Spayed Female',
#  'age_upon_outcome': '9 years',
#  'breed': 'Domestic Medium Hair',
#  'color': 'Torbie'}
